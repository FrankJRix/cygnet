# %%
import numpy as np
import uproot
import matplotlib.pyplot as plt

# %%
file = uproot.open("data/histograms_Run00001.root")
file.keys()
# Out:
# ['param_dir;1',
#  'param_dir/A;1',
#  'param_dir/GEANT4isotopes;1',
#  'param_dir/GEM1_HV;1',
#  'param_dir/GEM2_HV;1',
#  'param_dir/GEM3_HV;1',
#  'param_dir/NR;1',
#  'param_dir/Parallel_threads;1',
#  'param_dir/SRIM;1',
#  'param_dir/Vignetting;1',
#  'param_dir/WID;1',
#  'param_dir/absorption_l;1',
#  'param_dir/bckg;1',
#  'param_dir/beta;1',
#  'param_dir/camera_aperture;1',
#  'param_dir/diff_coeff_L;1',
#  'param_dir/diff_coeff_T;1',
#  'param_dir/diff_const_sigma0L;1',
#  'param_dir/diff_const_sigma0T;1',
#  'param_dir/donotremove;1',
#  'param_dir/events;1',
#  'param_dir/exposure_time;1',
#  'param_dir/exposure_time_effect;1',
#  'param_dir/fixed_seed;1',
#  'param_dir/ion_pot;1',
#  'param_dir/photons_per_el;1',
#  'param_dir/queue;1',
#  'param_dir/randZ_range;1',
#  'param_dir/random_ped;1',
#  'param_dir/redpix_output;1',
#  'param_dir/rootfiles;1',
#  'param_dir/saturation;1',
#  'param_dir/start_event;1',
#  'param_dir/start_run_number;1',
#  'param_dir/x_dim;1',
#  'param_dir/x_extra;1',
#  'param_dir/x_offset;1',
#  'param_dir/xy_vox_scale;1',
#  'param_dir/y_dim;1',
#  'param_dir/y_extra;1',
#  'param_dir/y_offset;1',
#  'param_dir/z_extra;1',
#  'param_dir/z_offset;1',
#  'param_dir/z_vox_dim;1',
#  'param_dir/zcloud;1',
#  'param_dir/pedestal_runs;1',
#  'pic_run1_ev0;1',
#  'pic_run1_ev1;1',
#  'pic_run1_ev2;1',
#  'pic_run1_ev3;1',
#  'pic_run1_ev4;1',
#  'pic_run1_ev5;1',
#  'pic_run1_ev6;1',
#  'pic_run1_ev7;1',
#  'pic_run1_ev8;1',
#  'pic_run1_ev9;1',
#  'pic_run1_ev10;1',
#  'pic_run1_ev11;1',
#  'pic_run1_ev12;1',
#  'pic_run1_ev13;1',
#  'pic_run1_ev14;1',
#  'pic_run1_ev15;1',
#  'pic_run1_ev16;1',
#  'pic_run1_ev17;1',
#  'pic_run1_ev18;1',
#  'pic_run1_ev19;1',
#  'pic_run1_ev20;1',
#  'pic_run1_ev21;1',
#  'pic_run1_ev22;1',
#  'pic_run1_ev23;1',
#  'pic_run1_ev24;1',
#  'pic_run1_ev25;1',
#  'pic_run1_ev26;1',
#  'pic_run1_ev27;1',
#  'pic_run1_ev28;1',
#  'pic_run1_ev29;1',
#  'pic_run1_ev30;1',
#  'pic_run1_ev31;1',
#  'pic_run1_ev32;1',
#  'pic_run1_ev33;1',
#  'pic_run1_ev34;1',
#  'pic_run1_ev35;1',
#  'pic_run1_ev36;1',
#  'pic_run1_ev37;1',
#  'pic_run1_ev38;1',
#  'pic_run1_ev39;1',
#  'pic_run1_ev40;1',
#  'pic_run1_ev41;1',
#  'pic_run1_ev42;1',
#  'pic_run1_ev43;1',
#  'pic_run1_ev44;1',
#  'pic_run1_ev45;1',
#  'pic_run1_ev46;1',
#  'pic_run1_ev47;1',
#  'pic_run1_ev48;1',
#  'pic_run1_ev49;1',
#  'pic_run1_ev50;1',
#  'pic_run1_ev51;1',
#  'pic_run1_ev52;1',
#  'pic_run1_ev53;1',
#  'pic_run1_ev54;1',
#  'pic_run1_ev55;1',
#  'pic_run1_ev56;1',
#  'pic_run1_ev57;1',
#  'pic_run1_ev58;1',
#  'pic_run1_ev59;1',
#  'pic_run1_ev60;1',
#  'pic_run1_ev61;1',
#  'pic_run1_ev62;1',
#  'pic_run1_ev63;1',
#  'pic_run1_ev64;1',
#  'pic_run1_ev65;1',
#  'pic_run1_ev66;1',
#  'pic_run1_ev67;1',
#  'pic_run1_ev68;1',
#  'pic_run1_ev69;1',
#  'pic_run1_ev70;1',
#  'pic_run1_ev71;1',
#  'pic_run1_ev72;1',
#  'pic_run1_ev73;1',
#  'pic_run1_ev74;1',
#  'pic_run1_ev75;1',
#  'pic_run1_ev76;1',
#  'pic_run1_ev77;1',
#  'pic_run1_ev78;1',
#  'pic_run1_ev79;1',
#  'pic_run1_ev80;1',
#  'pic_run1_ev81;1',
#  'pic_run1_ev82;1',
#  'pic_run1_ev83;1',
#  'pic_run1_ev84;1',
#  'pic_run1_ev85;1',
#  'pic_run1_ev86;1',
#  'pic_run1_ev87;1',
#  'pic_run1_ev88;1',
#  'pic_run1_ev89;1',
#  'pic_run1_ev90;1',
#  'pic_run1_ev91;1',
#  'pic_run1_ev92;1',
#  'pic_run1_ev93;1',
#  'pic_run1_ev94;1',
#  'pic_run1_ev95;1',
#  'pic_run1_ev96;1',
#  'pic_run1_ev97;1',
#  'pic_run1_ev98;1',
#  'pic_run1_ev99;1',
#  'pic_run1_ev100;1',
#  'pic_run1_ev101;1',
#  'pic_run1_ev102;1',
#  'pic_run1_ev103;1',
#  'pic_run1_ev104;1',
#  'pic_run1_ev105;1',
#  'pic_run1_ev106;1',
#  'pic_run1_ev107;1',
#  'pic_run1_ev108;1',
#  'pic_run1_ev109;1',
#  'pic_run1_ev110;1',
#  'pic_run1_ev111;1',
#  'pic_run1_ev112;1',
#  'pic_run1_ev113;1',
#  'pic_run1_ev114;1',
#  'pic_run1_ev115;1',
#  'pic_run1_ev116;1',
#  'pic_run1_ev117;1',
#  'pic_run1_ev118;1',
#  'pic_run1_ev119;1',
#  'pic_run1_ev120;1',
#  'pic_run1_ev121;1',
#  'pic_run1_ev122;1',
#  'pic_run1_ev123;1',
#  'pic_run1_ev124;1',
#  'pic_run1_ev125;1',
#  'pic_run1_ev126;1',
#  'pic_run1_ev127;1',
#  'pic_run1_ev128;1',
#  'pic_run1_ev129;1',
#  'pic_run1_ev130;1',
#  'pic_run1_ev131;1',
#  'pic_run1_ev132;1',
#  'pic_run1_ev133;1',
#  'pic_run1_ev134;1',
#  'pic_run1_ev135;1',
#  'pic_run1_ev136;1',
#  'pic_run1_ev137;1',
#  'pic_run1_ev138;1',
#  'pic_run1_ev139;1',
#  'pic_run1_ev140;1',
#  'pic_run1_ev141;1',
#  'pic_run1_ev142;1',
#  'pic_run1_ev143;1',
#  'pic_run1_ev144;1',
#  'pic_run1_ev145;1',
#  'pic_run1_ev146;1',
#  'pic_run1_ev147;1',
#  'pic_run1_ev148;1',
#  'pic_run1_ev149;1',
#  'pic_run1_ev150;1',
#  'pic_run1_ev151;1',
#  'pic_run1_ev152;1',
#  'pic_run1_ev153;1',
#  'pic_run1_ev154;1',
#  'pic_run1_ev155;1',
#  'pic_run1_ev156;1',
#  'pic_run1_ev157;1',
#  'pic_run1_ev158;1',
#  'pic_run1_ev159;1',
#  'pic_run1_ev160;1',
#  'pic_run1_ev161;1',
#  'pic_run1_ev162;1',
#  'pic_run1_ev163;1',
#  'pic_run1_ev164;1',
#  'pic_run1_ev165;1',
#  'pic_run1_ev166;1',
#  'pic_run1_ev167;1',
#  'pic_run1_ev168;1',
#  'pic_run1_ev169;1',
#  'pic_run1_ev170;1',
#  'pic_run1_ev171;1',
#  'pic_run1_ev172;1',
#  'pic_run1_ev173;1',
#  'pic_run1_ev174;1',
#  'pic_run1_ev175;1',
#  'pic_run1_ev176;1',
#  'pic_run1_ev177;1',
#  'pic_run1_ev178;1',
#  'pic_run1_ev179;1',
#  'pic_run1_ev180;1',
#  'pic_run1_ev181;1',
#  'pic_run1_ev182;1',
#  'pic_run1_ev183;1',
#  'pic_run1_ev184;1',
#  'pic_run1_ev185;1',
#  'pic_run1_ev186;1',
#  'pic_run1_ev187;1',
#  'pic_run1_ev188;1',
#  'pic_run1_ev189;1',
#  'pic_run1_ev190;1',
#  'pic_run1_ev191;1',
#  'pic_run1_ev192;1',
#  'pic_run1_ev193;1',
#  'pic_run1_ev194;1',
#  'pic_run1_ev195;1',
#  'pic_run1_ev196;1',
#  'pic_run1_ev197;1',
#  'pic_run1_ev198;1',
#  'pic_run1_ev199;1',
#  'event_info;1']

# %%
tree = file["event_info"]
print(tree.keys())

print("\n\n\n")
print(len(tree["eventnumber"].arrays(library="np")["eventnumber"]))
# Out:
# ['eventnumber', 'particle_type', 'energy', 'theta', 'phi', 'track_length_3D', 'proj_track_2D', 'x_vertex', 'y_vertex', 'z_vertex', 'x_vertex_end', 'y_vertex_end', 'z_vertex_end', 'x_min', 'x_max', 'y_min', 'y_max', 'z_min', 'z_max', 'N_photons', 'px', 'py', 'pz', 'nhits_og', 'nRedpix', 'redpix_ix', 'redpix_iy', 'redpix_iz']
#
#
#
#
# 200

# %%
i = 1

image = file[f"pic_run1_ev{i}"].to_numpy()
fig =plt.figure(figsize = (8,8))
plt.title(f"EVENT {i}")
plt.imshow(image[0].T, vmin = 99, vmax = 120)
plt.show()

# %%
# How to extract redpixes (example)

ixs = tree["redpix_ix"].arrays(library="np")["redpix_ix"]
iys = tree["redpix_iy"].arrays(library="np")["redpix_iy"]
izs = tree["redpix_iz"].arrays(library="np")["redpix_iz"]

# %%
# Choose the same image/event
ievent = i
ix_event = ixs[ievent]
iy_event = iys[ievent]
iz_event = izs[ievent]

# %%
# Determine image shape (optional: you may already know it)
max_x = 2304 #4096 for QUEST digitization
max_y = 2304

# Create and fill image
image = np.zeros((max_x, max_y), dtype=np.uint16)
image[ix_event, iy_event] = iz_event  # assumes no duplicates

# %%
# Display image
plt.figure(figsize=(10,10))
plt.imshow(image.T, origin='lower', cmap='viridis')
#plt.colorbar(label='redpix_iz')
plt.xlabel('redpix_ix')
plt.ylabel('redpix_iy')
# Flip y axis from max to 0
plt.gca().invert_yaxis()
plt.title('Image without pedestal (i.e. only redpixes) (Event 0)')
#plt.savefig("./redpix.pdf")
plt.show()
